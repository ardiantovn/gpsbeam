# %%
import sys
import pandas as pd
from IPython.display import display
pd.options.display.max_columns = None

sys.path.append('F:/repo/gpsbeam')

from src.config.data_config import DataConfig
from src.config.cnn_ed_rnn_model_config import ModelConfig
from src.config.experiment_config import ExperimentConfig
from src.experiment import RunExperiment

# %%
run_obj = RunExperiment(data_config =DataConfig(scenario_num=23,
                                                splitting_method='adjusted',
                                                train_val_test_split_frac=[0.65,0.15, 0.2],
                                                seednum=42
                                                ), 
              model_config=ModelConfig(model_arch_name='cnn-ed-gru-model',
                                       train_epoch=20,
                                       train_batch_size=8,
                                       test_batch_size=1024,
                                       use_early_stopping=False,
                                       device='cuda',
                                       model_input_column_list=["unit2to1_vector", "unit2_height_log"],
                                       zero_pad_nonconsecutive=True,
                                       ends_input_with_out_len_zeros=False,
                                       seq_len=8,
                                       out_len=3,
                                       cnn_channels=[128, 128],
                                       rnn_num_layers=1,
                                       rnn_hidden_size=128,
                                       mlp_layer_sizes=[64],
                                       rnn_dropout=0, # fix
                                       cnn_dropout=0, # fix
                                       adam_weight_decay=0, # fix
                                       loss_func_name='cross-entropy-loss',
                                       adam_learning_rate=5e-4, # fix
                                       adam_opt_milestone_list=[12, 18],
                                       ), 
              experiment_config=ExperimentConfig(
                  exp_folder_name='00_test_drone_cnn_ed_rnn_experiment',
                  exp_dict={
                      "model_arch_name": ['cnn-ed-gru-model'
                                        ],
                       "num_classes": [32]
                  })).run()
# Out:
# 2025-05-20 15:11:07.428 | DEBUG    | src.experiment:run:40 - updated model_config | model_arch_name to cnn-ed-gru-model
# 2025-05-20 15:11:07.428 | DEBUG    | src.experiment:run:36 - updated data_config |num_classes to 32
# 2025-05-20 15:11:07.428 | DEBUG    | src.experiment:run:40 - updated model_config | num_classes to 32
# 2025-05-20 15:11:07.428 | DEBUG    | src.experiment:run:40 - updated model_config | model_input_column_list to ['unit2to1_vector', 'unit2_height_log']
# 2025-05-20 15:11:29.571 | INFO     | src.data.dataprep:get_train_val_test_dataset:296 -
# Dataset is LOADED from f:/repo/gpsbeam\data/processed/Scenario23/dset_scenario23_seednum42_train0.65_test0.2_portion100_beam32_splitting_method_adjusted.hkl
# 2025-05-20 15:11:29.571 | INFO     | src.data.dataprep:get_train_val_test_dataset:311 -
#                     RAW DATASET INFO
#                     ------------------------------
#                     Scenario Num                                    : 23,
#                     Splitting Method                                : adjusted
#                     Portion Percentage                              : 100
#                     Training                                        : 7387 samples [64.87%]
#                     Validation                                      : 1694 samples [14.88%]
#                     Testing                                         : 2306 samples [20.25%]
#                     Total                                           : 11387 samples
#
# 2025-05-20 15:11:29.587 | INFO     | src.data.dataprep:get_train_val_test_dataset:321 - ------------------------------------------------------------------------------------------------------------------------------------------------------
# 2025-05-20 15:11:29.587 | INFO     | src.modelprep:_setup_paths:51 - model_recap_dir Name: f:/repo/gpsbeam\data/experiment_result/00_test_drone_cnn_ed_rnn_experiment_20052025_151107/model_recap
# 2025-05-20 15:11:29.587 | INFO     | src.config.experiment_config:show_config:46 -
# 	ExperimentConfig initialized with:
# 	 exp_folder_name=00_test_drone_cnn_ed_rnn_experiment_20052025_151107
# 	 exp_dict={'model_arch_name': ['cnn-ed-gru-model'], 'num_classes': [32]}
# 	 top_n_list=[1, 3, 5]
# 	 confidence_threshold_list=[0.8, 0.85, 0.9, 0.95, 0.99]
# 	 power_loss_db_threshold_list=[1, 3, 6]
# 	 day_time=20052025_151107
# 	 combinations=[{'model_arch_name': 'cnn-ed-gru-model', 'num_classes': 32, 'model_input_column_list': ['unit2to1_vector', 'unit2_height_log']}]
# 2025-05-20 15:11:29.587 | INFO     | src.config.data_config:show_config:35 -
# 	DataConfig initialized with:
# 	 scenario_num=23
# 	 seednum=42
# 	 splitting_method=adjusted
# 	 shuffle_sequential=False
# 	 num_classes=32
# 	 train_val_test_split_frac=[0.65, 0.15, 0.2]
# 	 portion_percentage=100
# 	 gps_calibrated_scenario_nums=[8, 9]
# 	 lidar_scr_scenario_nums=[8, 9]
# 	 lidar_scenario_nums=[31, 32, 33]
# 	 radar_scenario_nums=[9, 31, 32, 33]
# 	 label_column_name=unit1_beam_idx_32
# 	 train_frac=0.65
# 	 val_frac=0.15
# 	 test_frac=0.2
# 2025-05-20 15:11:29.587 | INFO     | src.config.abstract_config:show_config:42 -
# 	ModelConfig initialized with:
# 	 model_arch_name=cnn-ed-gru-model
# 	 train_epoch=20
# 	 train_batch_size=8
# 	 val_batch_size=1024
# 	 test_batch_size=1024
# 	 num_worker=0
# 	 optimizer_name=adam
# 	 adam_learning_rate=0.0005
# 	 adam_weight_decay=0
# 	 adam_opt_milestone_list=[12, 18]
# 	 adam_opt_gamma=0.1
# 	 loss_func_name=cross-entropy-loss
# 	 weight_balancing_method=none
# 	 use_early_stopping=False
# 	 early_stop_patience=10
# 	 early_stop_min_delta=0.001
# 	 device=cuda
# 	 model_input_column_list=['unit2to1_vector', 'unit2_height_log']
# 	 cnn_channels=[128, 128]
# 	 num_classes=32
# 	 rnn_num_layers=1
# 	 rnn_hidden_size=128
# 	 rnn_dropout=0
# 	 cnn_dropout=0
# 	 mlp_layer_sizes=[64]
# 	 shuffle_train_dset=True
# 	 seq_len=8
# 	 out_len=3
# 	 zero_pad_nonconsecutive=True
# 	 ends_input_with_out_len_zeros=False
# 	 dl_task_type=beam_tracking
# 	 feature_groups={1: ['unit2_speed', 'unit2_altitude', 'unit2_distance', 'unit2_height', 'unit2_x-speed', 'unit2_y-speed', 'unit2_z-speed', 'unit2_pitch', 'unit2_roll', 'sample_idx', 'unit2_height_log', 'unit2_height_minmax_norm'], 2: ['unit2_loc_minmax_norm', 'unit2_loc'], 3: ['unit2to1_vector', 'unit1_loc_vector', 'unit2_loc_vector'], 8: ['unit1_beam_idx_8'], 16: ['unit1_beam_idx_16'], 32: ['unit1_beam_idx_32'], 64: ['unit1_beam_idx_64'], 216: ['unit1_lidar_scr', 'unit1_lidar']}
# 	 label_column_name=unit1_beam_idx_32
# 	 pred_num=4
# 	 feature_len=4
# 2025-05-20 15:11:29.587 | INFO     | src.modelprep:_setup_data_loaders:156 -
#                     RAW DATASET INFO
#                     ------------------------------
#                     Scenario Num                                    : 23,
#                     SplittingMethod                                 : adjusted
#                     Portion Percentage                              : 100
#                     Training                                        : 7387 samples [64.87%]
#                     Validation                                      : 1694 samples [14.88%]
#                     Testing                                         : 2306 samples [20.25%]
#                     Train Dataset Entropy                           : 2.65
#                     Total                                           : 11387 samples
#
# 2025-05-20 15:11:29.587 | DEBUG    | src.preprocessor.gpsprep:__init__:8 - GpsPrep Initialized.
# 2025-05-20 15:11:44.833 | DEBUG    | src.preprocessor.gpsprep:__init__:8 - GpsPrep Initialized.
# 2025-05-20 15:11:49.258 | DEBUG    | src.preprocessor.gpsprep:__init__:8 - GpsPrep Initialized.
# 2025-05-20 15:11:54.258 | INFO     | src.modelprep:_setup_data_loaders:190 -
#                     FILTERED DATASET INFO
#                     ------------------------------
#                     Scenario Num                                    : 23,
#                     SplittingMethod                                 : adjusted
#                     Portion Percentage                              : 100
#                     Training                                        : 7093 samples [67.00%]
#                     Validation                                      : 1444 samples [13.64%]
#                     Testing                                         : 2050 samples [19.36%]
#                     Total                                           : 10587 samples
#
# 2025-05-20 15:11:54.275 | INFO     | src.modelprep:_setup_data_loaders:200 - ------------------------------------------------------------------------------------------------------------------------------------------------------
# Training: 100%|██████████| 887/887 [00:09<00:00, 96.68it/s]
# val: 100%|██████████| 2/2 [00:00<00:00, 66.56it/s]
# 2025-05-20 15:12:05.117 | DEBUG    | src.utils.metric_handler:calculate_final_metrics_batch_first:81 -
# [[0.089 0.081 0.087 0.098]
#  [0.337 0.329 0.355 0.356]
#  [0.564 0.539 0.572 0.557]]
# 2025-05-20 15:12:05.156 | DEBUG    | src.modelprep:_save_best_model:765 -
# EPOCH 1 |updated best pred0_top1_val_acc_percent: 8.9 %
# Training: 100%|██████████| 887/887 [00:11<00:00, 74.91it/s]
# val: 100%|██████████| 2/2 [00:00<00:00, 63.98it/s]
# 2025-05-20 15:12:17.029 | DEBUG    | src.utils.metric_handler:calculate_final_metrics_batch_first:81 -
# [[0.24  0.241 0.254 0.231]
#  [0.751 0.739 0.734 0.711]
#  [0.922 0.921 0.911 0.906]]
# 2025-05-20 15:12:17.072 | DEBUG    | src.modelprep:_save_best_model:765 -
# EPOCH 2 |updated best pred0_top1_val_acc_percent: 24.0 %
# Training: 100%|██████████| 887/887 [00:12<00:00, 73.72it/s]
# val: 100%|██████████| 2/2 [00:00<00:00, 107.64it/s]
# 2025-05-20 15:12:29.141 | DEBUG    | src.utils.metric_handler:calculate_final_metrics_batch_first:81 -
# [[0.378 0.362 0.367 0.352]
#  [0.795 0.798 0.806 0.783]
#  [0.935 0.943 0.939 0.931]]
# 2025-05-20 15:12:29.180 | DEBUG    | src.modelprep:_save_best_model:765 -
# EPOCH 3 |updated best pred0_top1_val_acc_percent: 37.8 %
# Training: 100%|██████████| 887/887 [00:12<00:00, 73.80it/s]
# val: 100%|██████████| 2/2 [00:00<00:00, 49.86it/s]
# 2025-05-20 15:12:41.242 | DEBUG    | src.utils.metric_handler:calculate_final_metrics_batch_first:81 -
# [[0.555 0.55  0.524 0.491]
#  [0.911 0.913 0.904 0.884]
#  [0.975 0.974 0.965 0.958]]
# 2025-05-20 15:12:41.288 | DEBUG    | src.modelprep:_save_best_model:765 -
# EPOCH 4 |updated best pred0_top1_val_acc_percent: 55.5 %
# Training: 100%|██████████| 887/887 [00:12<00:00, 73.75it/s]
# val: 100%|██████████| 2/2 [00:00<00:00, 52.88it/s]
# 2025-05-20 15:12:53.354 | DEBUG    | src.utils.metric_handler:calculate_final_metrics_batch_first:81 -
# [[0.594 0.584 0.575 0.542]
#  [0.923 0.925 0.912 0.898]
#  [0.97  0.967 0.96  0.955]]
# 2025-05-20 15:12:53.417 | DEBUG    | src.modelprep:_save_best_model:765 -
# EPOCH 5 |updated best pred0_top1_val_acc_percent: 59.4 %
# Training: 100%|██████████| 887/887 [00:11<00:00, 74.46it/s]
# val: 100%|██████████| 2/2 [00:00<00:00, 57.40it/s]
# 2025-05-20 15:13:05.366 | DEBUG    | src.utils.metric_handler:calculate_final_metrics_batch_first:81 -
# [[0.539 0.521 0.487 0.479]
#  [0.893 0.883 0.86  0.837]
#  [0.958 0.949 0.938 0.927]]
# 2025-05-20 15:13:05.552 | DEBUG    | src.modelprep:_save_best_model:765 -
# EPOCH 6 |updated best pred0_top1_val_acc_percent: 59.4 %
# Training: 100%|██████████| 887/887 [00:12<00:00, 73.88it/s]
# val: 100%|██████████| 2/2 [00:00<00:00, 60.34it/s]
# 2025-05-20 15:13:17.607 | DEBUG    | src.utils.metric_handler:calculate_final_metrics_batch_first:81 -
# [[0.672 0.648 0.623 0.598]
#  [0.946 0.943 0.923 0.908]
#  [0.977 0.973 0.967 0.955]]
# 2025-05-20 15:13:17.647 | DEBUG    | src.modelprep:_save_best_model:765 -
# EPOCH 7 |updated best pred0_top1_val_acc_percent: 67.2 %
# Training: 100%|██████████| 887/887 [00:11<00:00, 74.28it/s]
# val: 100%|██████████| 2/2 [00:00<00:00, 62.07it/s]
# 2025-05-20 15:13:29.623 | DEBUG    | src.utils.metric_handler:calculate_final_metrics_batch_first:81 -
# [[0.552 0.551 0.553 0.513]
#  [0.889 0.898 0.889 0.87 ]
#  [0.972 0.973 0.968 0.961]]
# 2025-05-20 15:13:29.656 | DEBUG    | src.modelprep:_save_best_model:765 -
# EPOCH 8 |updated best pred0_top1_val_acc_percent: 67.2 %
# Training: 100%|██████████| 887/887 [00:11<00:00, 74.58it/s]
# val: 100%|██████████| 2/2 [00:00<00:00, 61.86it/s]
# 2025-05-20 15:13:41.581 | DEBUG    | src.utils.metric_handler:calculate_final_metrics_batch_first:81 -
# [[0.518 0.511 0.483 0.49 ]
#  [0.904 0.901 0.87  0.848]
#  [0.969 0.966 0.956 0.938]]
# 2025-05-20 15:13:41.623 | DEBUG    | src.modelprep:_save_best_model:765 -
# EPOCH 9 |updated best pred0_top1_val_acc_percent: 67.2 %
# Training: 100%|██████████| 887/887 [00:11<00:00, 74.40it/s]
# val: 100%|██████████| 2/2 [00:00<00:00, 63.98it/s]
# 2025-05-20 15:13:53.575 | DEBUG    | src.utils.metric_handler:calculate_final_metrics_batch_first:81 -
# [[0.588 0.589 0.58  0.55 ]
#  [0.937 0.943 0.935 0.908]
#  [0.976 0.976 0.97  0.96 ]]
# 2025-05-20 15:13:53.618 | DEBUG    | src.modelprep:_save_best_model:765 -
# EPOCH 10 |updated best pred0_top1_val_acc_percent: 67.2 %
# Training: 100%|██████████| 887/887 [00:11<00:00, 74.08it/s]
# val: 100%|██████████| 2/2 [00:00<00:00, 39.26it/s]
# 2025-05-20 15:14:05.646 | DEBUG    | src.utils.metric_handler:calculate_final_metrics_batch_first:81 -
# [[0.545 0.526 0.505 0.502]
#  [0.943 0.918 0.908 0.884]
#  [0.974 0.97  0.954 0.943]]
# 2025-05-20 15:14:05.677 | DEBUG    | src.modelprep:_save_best_model:765 -
# EPOCH 11 |updated best pred0_top1_val_acc_percent: 67.2 %
# Training: 100%|██████████| 887/887 [00:11<00:00, 74.77it/s]
# val: 100%|██████████| 2/2 [00:00<00:00, 57.06it/s]
# 2025-05-20 15:14:17.575 | DEBUG    | src.utils.metric_handler:calculate_final_metrics_batch_first:81 -
# [[0.617 0.609 0.605 0.558]
#  [0.949 0.945 0.93  0.911]
#  [0.98  0.98  0.972 0.96 ]]
# 2025-05-20 15:14:17.618 | DEBUG    | src.modelprep:_save_best_model:765 -
# EPOCH 12 |updated best pred0_top1_val_acc_percent: 67.2 %
# Training: 100%|██████████| 887/887 [00:09<00:00, 97.38it/s]
# val: 100%|██████████| 2/2 [00:00<00:00, 77.36it/s]
# 2025-05-20 15:14:26.755 | DEBUG    | src.utils.metric_handler:calculate_final_metrics_batch_first:81 -
# [[0.711 0.711 0.684 0.645]
#  [0.966 0.956 0.945 0.925]
#  [0.984 0.983 0.974 0.963]]
# 2025-05-20 15:14:26.795 | DEBUG    | src.modelprep:_save_best_model:765 -
# EPOCH 13 |updated best pred0_top1_val_acc_percent: 71.1 %
# Training: 100%|██████████| 887/887 [00:06<00:00, 143.24it/s]
# val: 100%|██████████| 2/2 [00:00<00:00, 87.97it/s]
# 2025-05-20 15:14:33.015 | DEBUG    | src.utils.metric_handler:calculate_final_metrics_batch_first:81 -
# [[0.703 0.702 0.678 0.637]
#  [0.967 0.96  0.94  0.918]
#  [0.983 0.983 0.974 0.961]]
# 2025-05-20 15:14:33.050 | DEBUG    | src.modelprep:_save_best_model:765 -
# EPOCH 14 |updated best pred0_top1_val_acc_percent: 71.1 %
# Training: 100%|██████████| 887/887 [00:05<00:00, 157.16it/s]
# val: 100%|██████████| 2/2 [00:00<00:00, 87.87it/s]
# 2025-05-20 15:14:38.722 | DEBUG    | src.utils.metric_handler:calculate_final_metrics_batch_first:81 -
# [[0.693 0.691 0.668 0.634]
#  [0.968 0.961 0.939 0.921]
#  [0.982 0.983 0.973 0.96 ]]
# 2025-05-20 15:14:38.761 | DEBUG    | src.modelprep:_save_best_model:765 -
# EPOCH 15 |updated best pred0_top1_val_acc_percent: 71.1 %
# Training: 100%|██████████| 887/887 [00:05<00:00, 150.41it/s]
# val: 100%|██████████| 2/2 [00:00<00:00, 69.12it/s]
# 2025-05-20 15:14:44.692 | DEBUG    | src.utils.metric_handler:calculate_final_metrics_batch_first:81 -
# [[0.7   0.693 0.663 0.632]
#  [0.969 0.958 0.939 0.92 ]
#  [0.982 0.981 0.973 0.961]]
# 2025-05-20 15:14:44.954 | DEBUG    | src.modelprep:_save_best_model:765 -
# EPOCH 16 |updated best pred0_top1_val_acc_percent: 71.1 %
# Training: 100%|██████████| 887/887 [00:08<00:00, 101.32it/s]
# val: 100%|██████████| 2/2 [00:00<00:00, 70.66it/s]
# 2025-05-20 15:14:53.742 | DEBUG    | src.utils.metric_handler:calculate_final_metrics_batch_first:81 -
# [[0.697 0.713 0.686 0.645]
#  [0.969 0.966 0.948 0.924]
#  [0.983 0.983 0.974 0.965]]
# 2025-05-20 15:14:53.770 | DEBUG    | src.modelprep:_save_best_model:765 -
# EPOCH 17 |updated best pred0_top1_val_acc_percent: 71.1 %
# Training: 100%|██████████| 887/887 [00:08<00:00, 99.99it/s]
# val: 100%|██████████| 2/2 [00:00<00:00, 104.25it/s]
# 2025-05-20 15:15:02.678 | DEBUG    | src.utils.metric_handler:calculate_final_metrics_batch_first:81 -
# [[0.699 0.699 0.677 0.639]
#  [0.967 0.965 0.953 0.931]
#  [0.983 0.983 0.975 0.965]]
# 2025-05-20 15:15:02.731 | DEBUG    | src.modelprep:_save_best_model:765 -
# EPOCH 18 |updated best pred0_top1_val_acc_percent: 71.1 %
# Training: 100%|██████████| 887/887 [00:08<00:00, 100.70it/s]
# val: 100%|██████████| 2/2 [00:00<00:00, 73.77it/s]
# 2025-05-20 15:15:11.572 | DEBUG    | src.utils.metric_handler:calculate_final_metrics_batch_first:81 -
# [[0.701 0.691 0.664 0.63 ]
#  [0.971 0.959 0.942 0.922]
#  [0.984 0.983 0.974 0.961]]
# 2025-05-20 15:15:11.610 | DEBUG    | src.modelprep:_save_best_model:765 -
# EPOCH 19 |updated best pred0_top1_val_acc_percent: 71.1 %
# Training: 100%|██████████| 887/887 [00:08<00:00, 100.59it/s]
# val: 100%|██████████| 2/2 [00:00<00:00, 70.45it/s]
# 2025-05-20 15:15:20.464 | DEBUG    | src.utils.metric_handler:calculate_final_metrics_batch_first:81 -
# [[0.692 0.698 0.668 0.641]
#  [0.97  0.96  0.942 0.922]
#  [0.983 0.983 0.973 0.961]]
# 2025-05-20 15:15:20.502 | DEBUG    | src.modelprep:_save_best_model:765 -
# EPOCH 20 |updated best pred0_top1_val_acc_percent: 71.1 %
# Saving plot data to f:/repo/gpsbeam\data/experiment_result/00_test_drone_cnn_ed_rnn_experiment_20052025_151107\05-20-2025_15_11_29\dl_generated/model_measurement/label_distribution_data_scenario_23_sampling_adjusted.csv
# Saving plot to f:/repo/gpsbeam\data/experiment_result/00_test_drone_cnn_ed_rnn_experiment_20052025_151107\05-20-2025_15_11_29\dl_generated/model_measurement/label_distribution_scenario_23_sampling_adjusted.pdf
# 2025-05-20 15:15:21.332 | DEBUG    | src.modelprep:_load_best_checkpoint:550 - Get Model: cnn-ed-gru-model
#                          NUM CLASSES: 32
# 2025-05-20 15:15:21.348 | INFO     | src.modelprep:_load_best_checkpoint:553 - Model loaded from f:/repo/gpsbeam\data/experiment_result/00_test_drone_cnn_ed_rnn_experiment_20052025_151107\05-20-2025_15_11_29\dl_generated/model_checkpoint/arch_cnn-ed-gru-model_nclass_32_.pth
# Saved plot to f:/repo/gpsbeam\data/experiment_result/00_test_drone_cnn_ed_rnn_experiment_20052025_151107\05-20-2025_15_11_29\dl_generated/model_measurement/train_val_loss_vs_epochs.pdf
# test: 100%|██████████| 3/3 [00:00<00:00, 62.14it/s]
# 2025-05-20 15:15:21.432 | DEBUG    | src.utils.metric_handler:calculate_final_metrics_batch_first:81 -
# [[0.753 0.767 0.75  0.715]
#  [0.962 0.972 0.962 0.952]
#  [0.985 0.99  0.987 0.977]]
# 2025-05-20 15:15:26.725 | INFO     | src.modelprep:_save_inference_detail:661 - Saved inference detail to f:/repo/gpsbeam\data/experiment_result/00_test_drone_cnn_ed_rnn_experiment_20052025_151107\05-20-2025_15_11_29\dl_generated/model_inference_result/test_epoch_00_inference_detail.csv
# c:\Users\vendi\AppData\Local\pypoetry\Cache\virtualenvs\geobeam-3fwD9wo9-py3.9\lib\site-packages\torch\onnx\symbolic_opset9.py:4244: UserWarning: Exporting a model to ONNX with a batch_size other than 1, with a variable length with GRU can cause an error when running the ONNX model with a different batch size. Make sure to save the model with a batch size of 1, or define the initial states (h0/c0) as inputs of the model.
#   warnings.warn(
# 2025-05-20 15:15:26.918 | INFO     | src.modelprep:test:501 - Saved ONNX model to f:/repo/gpsbeam\data/experiment_result/00_test_drone_cnn_ed_rnn_experiment_20052025_151107\05-20-2025_15_11_29\dl_generated/model_checkpoint/arch_cnn-ed-gru-model_nclass_32_.onnx
# 2025-05-20 15:15:26.918 | INFO     | src.modelprep:test:503 - TEST RESULTS
# 2025-05-20 15:15:26.918 | INFO     | src.modelprep:test:506 - pred0_top1_test_acc_percent: 75.3
# 2025-05-20 15:15:26.918 | INFO     | src.modelprep:test:506 - pred0_top3_test_acc_percent: 96.2
# 2025-05-20 15:15:26.918 | INFO     | src.modelprep:test:506 - pred0_top5_test_acc_percent: 98.5
# 2025-05-20 15:15:26.918 | INFO     | src.modelprep:test:506 - pred1_top1_test_acc_percent: 76.7
# 2025-05-20 15:15:26.918 | INFO     | src.modelprep:test:506 - pred1_top3_test_acc_percent: 97.2
# 2025-05-20 15:15:26.918 | INFO     | src.modelprep:test:506 - pred1_top5_test_acc_percent: 99.0
# 2025-05-20 15:15:26.918 | INFO     | src.modelprep:test:506 - pred2_top1_test_acc_percent: 75.0
# 2025-05-20 15:15:26.918 | INFO     | src.modelprep:test:506 - pred2_top3_test_acc_percent: 96.2
# 2025-05-20 15:15:26.918 | INFO     | src.modelprep:test:506 - pred2_top5_test_acc_percent: 98.7
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:506 - pred3_top1_test_acc_percent: 71.5
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:506 - pred3_top3_test_acc_percent: 95.2
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:506 - pred3_top5_test_acc_percent: 97.7
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:510 - scenario_num: 23
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:510 - avg_loss: 1.579
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:510 - model_size_MiB: 0.99
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:510 - pred0_top1_mean_power_loss_db: 0.328
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:510 - pred1_top1_mean_power_loss_db: 0.345
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:510 - pred2_top1_mean_power_loss_db: 0.397
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:510 - pred3_top1_mean_power_loss_db: 0.836
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:510 - pred0_top1_n_beams_for_80pct_conf: 1.907
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:510 - pred1_top1_n_beams_for_80pct_conf: 1.897
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:510 - pred2_top1_n_beams_for_80pct_conf: 1.9
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:510 - pred3_top1_n_beams_for_80pct_conf: 1.904
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:510 - pred0_top1_overhead_saving_for_80pct_conf: 94.04
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:510 - pred1_top1_overhead_saving_for_80pct_conf: 94.073
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:510 - pred2_top1_overhead_saving_for_80pct_conf: 94.061
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:510 - pred3_top1_overhead_saving_for_80pct_conf: 94.049
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:510 - pred0_top1_n_beams_for_85pct_conf: 2.084
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:510 - pred1_top1_n_beams_for_85pct_conf: 2.086
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:510 - pred2_top1_n_beams_for_85pct_conf: 2.095
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:510 - pred3_top1_n_beams_for_85pct_conf: 2.104
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:510 - pred0_top1_overhead_saving_for_85pct_conf: 93.488
# 2025-05-20 15:15:26.934 | INFO     | src.modelprep:test:510 - pred1_top1_overhead_saving_for_85pct_conf: 93.482
# 2025-05-20 15:15:26.949 | INFO     | src.modelprep:test:510 - pred2_top1_overhead_saving_for_85pct_conf: 93.454
# 2025-05-20 15:15:26.949 | INFO     | src.modelprep:test:510 - pred3_top1_overhead_saving_for_85pct_conf: 93.425
# 2025-05-20 15:15:26.949 | INFO     | src.modelprep:test:510 - pred0_top1_n_beams_for_90pct_conf: 2.393
# 2025-05-20 15:15:26.949 | INFO     | src.modelprep:test:510 - pred1_top1_n_beams_for_90pct_conf: 2.394
# 2025-05-20 15:15:26.949 | INFO     | src.modelprep:test:510 - pred2_top1_n_beams_for_90pct_conf: 2.394
# 2025-05-20 15:15:26.949 | INFO     | src.modelprep:test:510 - pred3_top1_n_beams_for_90pct_conf: 2.396
# 2025-05-20 15:15:26.949 | INFO     | src.modelprep:test:510 - pred0_top1_overhead_saving_for_90pct_conf: 92.523
# 2025-05-20 15:15:26.949 | INFO     | src.modelprep:test:510 - pred1_top1_overhead_saving_for_90pct_conf: 92.518
# 2025-05-20 15:15:26.949 | INFO     | src.modelprep:test:510 - pred2_top1_overhead_saving_for_90pct_conf: 92.52
# 2025-05-20 15:15:26.949 | INFO     | src.modelprep:test:510 - pred3_top1_overhead_saving_for_90pct_conf: 92.512
# 2025-05-20 15:15:26.949 | INFO     | src.modelprep:test:510 - pred0_top1_n_beams_for_95pct_conf: 2.996
# 2025-05-20 15:15:26.949 | INFO     | src.modelprep:test:510 - pred1_top1_n_beams_for_95pct_conf: 3.007
# 2025-05-20 15:15:26.949 | INFO     | src.modelprep:test:510 - pred2_top1_n_beams_for_95pct_conf: 3.029
# 2025-05-20 15:15:26.949 | INFO     | src.modelprep:test:510 - pred3_top1_n_beams_for_95pct_conf: 3.05
# 2025-05-20 15:15:26.949 | INFO     | src.modelprep:test:510 - pred0_top1_overhead_saving_for_95pct_conf: 90.637
# 2025-05-20 15:15:26.949 | INFO     | src.modelprep:test:510 - pred1_top1_overhead_saving_for_95pct_conf: 90.604
# 2025-05-20 15:15:26.949 | INFO     | src.modelprep:test:510 - pred2_top1_overhead_saving_for_95pct_conf: 90.535
# 2025-05-20 15:15:26.949 | INFO     | src.modelprep:test:510 - pred3_top1_overhead_saving_for_95pct_conf: 90.468
# 2025-05-20 15:15:26.949 | INFO     | src.modelprep:test:510 - pred0_top1_n_beams_for_99pct_conf: 4.668
# 2025-05-20 15:15:26.949 | INFO     | src.modelprep:test:510 - pred1_top1_n_beams_for_99pct_conf: 4.706
# 2025-05-20 15:15:26.949 | INFO     | src.modelprep:test:510 - pred2_top1_n_beams_for_99pct_conf: 4.774
# 2025-05-20 15:15:26.949 | INFO     | src.modelprep:test:510 - pred3_top1_n_beams_for_99pct_conf: 4.821
# 2025-05-20 15:15:26.965 | INFO     | src.modelprep:test:510 - pred0_top1_overhead_saving_for_99pct_conf: 85.413
# 2025-05-20 15:15:26.965 | INFO     | src.modelprep:test:510 - pred1_top1_overhead_saving_for_99pct_conf: 85.293
# 2025-05-20 15:15:26.965 | INFO     | src.modelprep:test:510 - pred2_top1_overhead_saving_for_99pct_conf: 85.082
# 2025-05-20 15:15:26.965 | INFO     | src.modelprep:test:510 - pred3_top1_overhead_saving_for_99pct_conf: 84.934
# 2025-05-20 15:15:26.965 | INFO     | src.modelprep:test:510 - pred0_top1_reliability_power_loss_leq_1db_pct: 95.268
# 2025-05-20 15:15:26.965 | INFO     | src.modelprep:test:510 - pred1_top1_reliability_power_loss_leq_1db_pct: 96.0
# 2025-05-20 15:15:26.965 | INFO     | src.modelprep:test:510 - pred2_top1_reliability_power_loss_leq_1db_pct: 95.805
# 2025-05-20 15:15:26.965 | INFO     | src.modelprep:test:510 - pred3_top1_reliability_power_loss_leq_1db_pct: 93.415
# 2025-05-20 15:15:26.965 | INFO     | src.modelprep:test:510 - pred0_top1_reliability_power_loss_leq_3db_pct: 98.878
# 2025-05-20 15:15:26.965 | INFO     | src.modelprep:test:510 - pred1_top1_reliability_power_loss_leq_3db_pct: 99.171
# 2025-05-20 15:15:26.965 | INFO     | src.modelprep:test:510 - pred2_top1_reliability_power_loss_leq_3db_pct: 98.244
# 2025-05-20 15:15:26.965 | INFO     | src.modelprep:test:510 - pred3_top1_reliability_power_loss_leq_3db_pct: 97.317
# 2025-05-20 15:15:26.965 | INFO     | src.modelprep:test:510 - pred0_top1_reliability_power_loss_leq_6db_pct: 99.61
# 2025-05-20 15:15:26.965 | INFO     | src.modelprep:test:510 - pred1_top1_reliability_power_loss_leq_6db_pct: 99.463
# 2025-05-20 15:15:26.965 | INFO     | src.modelprep:test:510 - pred2_top1_reliability_power_loss_leq_6db_pct: 99.317
# 2025-05-20 15:15:26.965 | INFO     | src.modelprep:test:510 - pred3_top1_reliability_power_loss_leq_6db_pct: 98.634
# 2025-05-20 15:15:26.965 | INFO     | src.modelprep:test:513 - Model Architecture:
# 2025-05-20 15:15:26.965 | INFO     | src.modelprep:test:514 - CnnEdGruModel(
#   (conv_layers): ModuleList(
#     (0): Conv1d(4, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#     (1): Conv1d(128, 128, kernel_size=(3,), stride=(1,), padding=(1,))
#   )
#   (bn): BatchNorm1d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU()
#   (dropout): Dropout(p=0, inplace=False)
#   (encoder_rnn): GRU(128, 128, batch_first=True)
#   (decoder_rnn): GRU(128, 128, batch_first=True)
#   (mlp_layers): Sequential(
#     (0): Linear(in_features=128, out_features=64, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=64, out_features=32, bias=True)
#   )
# )
# 2025-05-20 15:15:26.981 | INFO     | src.experiment:run:79 - Model recap saved at f:/repo/gpsbeam\data/experiment_result/00_test_drone_cnn_ed_rnn_experiment_20052025_151107/model_recap

# %%
fname = r'F:\repo\gpsbeam\data\experiment_result\00_test_drone_cnn_ed_rnn_experiment_20052025_151107\model_recap\exp_test_result_recap.csv'
df = pd.read_csv(fname)
# sort by pred0_top1_test_acc_percent
df = df.sort_values(by='pred0_top1_test_acc_percent', ascending=False)
df.head(15)
# Out:
#     model_arch_name  num_classes                  model_input_column_list  \
# 0  cnn-ed-gru-model           32  ['unit2to1_vector', 'unit2_height_log']
#
#    scenario_num  avg_loss  model_size_MiB  pred0_top1_mean_power_loss_db  \
# 0            23     1.579            0.99                          0.328
#
#    pred1_top1_mean_power_loss_db  pred2_top1_mean_power_loss_db  \
# 0                          0.345                          0.397
#
#    pred3_top1_mean_power_loss_db  pred0_top1_n_beams_for_80pct_conf  \
# 0                          0.836                              1.907
#
#    pred1_top1_n_beams_for_80pct_conf  pred2_top1_n_beams_for_80pct_conf  \
# 0                              1.897                                1.9
#
#    pred3_top1_n_beams_for_80pct_conf  \
# 0                              1.904
#
#    pred0_top1_overhead_saving_for_80pct_conf  \
# 0                                      94.04
#
#    pred1_top1_overhead_saving_for_80pct_conf  \
# 0                                     94.073
#
#    pred2_top1_overhead_saving_for_80pct_conf  \
# 0                                     94.061
#
#    pred3_top1_overhead_saving_for_80pct_conf  \
# 0                                     94.049
#
#    pred0_top1_n_beams_for_85pct_conf  pred1_top1_n_beams_for_85pct_conf  \
# 0                              2.084                              2.086
#
#    pred2_top1_n_beams_for_85pct_conf  pred3_top1_n_beams_for_85pct_conf  \
# 0                              2.095                              2.104
#
#    pred0_top1_overhead_saving_for_85pct_conf  \
# 0                                     93.488
#
#    pred1_top1_overhead_saving_for_85pct_conf  \
# 0                                     93.482
#
#    pred2_top1_overhead_saving_for_85pct_conf  \
# 0                                     93.454
#
#    pred3_top1_overhead_saving_for_85pct_conf  \
# 0                                     93.425
#
#    pred0_top1_n_beams_for_90pct_conf  pred1_top1_n_beams_for_90pct_conf  \
# 0                              2.393                              2.394
#
#    pred2_top1_n_beams_for_90pct_conf  pred3_top1_n_beams_for_90pct_conf  \
# 0                              2.394                              2.396
#
#    pred0_top1_overhead_saving_for_90pct_conf  \
# 0                                     92.523
#
#    pred1_top1_overhead_saving_for_90pct_conf  \
# 0                                     92.518
#
#    pred2_top1_overhead_saving_for_90pct_conf  \
# 0                                      92.52
#
#    pred3_top1_overhead_saving_for_90pct_conf  \
# 0                                     92.512
#
#    pred0_top1_n_beams_for_95pct_conf  pred1_top1_n_beams_for_95pct_conf  \
# 0                              2.996                              3.007
#
#    pred2_top1_n_beams_for_95pct_conf  pred3_top1_n_beams_for_95pct_conf  \
# 0                              3.029                               3.05
#
#    pred0_top1_overhead_saving_for_95pct_conf  \
# 0                                     90.637
#
#    pred1_top1_overhead_saving_for_95pct_conf  \
# 0                                     90.604
#
#    pred2_top1_overhead_saving_for_95pct_conf  \
# 0                                     90.535
#
#    pred3_top1_overhead_saving_for_95pct_conf  \
# 0                                     90.468
#
#    pred0_top1_n_beams_for_99pct_conf  pred1_top1_n_beams_for_99pct_conf  \
# 0                              4.668                              4.706
#
#    pred2_top1_n_beams_for_99pct_conf  pred3_top1_n_beams_for_99pct_conf  \
# 0                              4.774                              4.821
#
#    pred0_top1_overhead_saving_for_99pct_conf  \
# 0                                     85.413
#
#    pred1_top1_overhead_saving_for_99pct_conf  \
# 0                                     85.293
#
#    pred2_top1_overhead_saving_for_99pct_conf  \
# 0                                     85.082
#
#    pred3_top1_overhead_saving_for_99pct_conf  \
# 0                                     84.934
#
#    pred0_top1_reliability_power_loss_leq_1db_pct  \
# 0                                         95.268
#
#    pred1_top1_reliability_power_loss_leq_1db_pct  \
# 0                                           96.0
#
#    pred2_top1_reliability_power_loss_leq_1db_pct  \
# 0                                         95.805
#
#    pred3_top1_reliability_power_loss_leq_1db_pct  \
# 0                                         93.415
#
#    pred0_top1_reliability_power_loss_leq_3db_pct  \
# 0                                         98.878
#
#    pred1_top1_reliability_power_loss_leq_3db_pct  \
# 0                                         99.171
#
#    pred2_top1_reliability_power_loss_leq_3db_pct  \
# 0                                         98.244
#
#    pred3_top1_reliability_power_loss_leq_3db_pct  \
# 0                                         97.317
#
#    pred0_top1_reliability_power_loss_leq_6db_pct  \
# 0                                          99.61
#
#    pred1_top1_reliability_power_loss_leq_6db_pct  \
# 0                                         99.463
#
#    pred2_top1_reliability_power_loss_leq_6db_pct  \
# 0                                         99.317
#
#    pred3_top1_reliability_power_loss_leq_6db_pct  pred0_top1_test_acc_percent  \
# 0                                         98.634                         75.3
#
#    pred0_top3_test_acc_percent  pred0_top5_test_acc_percent  \
# 0                         96.2                         98.5
#
#    pred1_top1_test_acc_percent  pred1_top3_test_acc_percent  \
# 0                         76.7                         97.2
#
#    pred1_top5_test_acc_percent  pred2_top1_test_acc_percent  \
# 0                         99.0                         75.0
#
#    pred2_top3_test_acc_percent  pred2_top5_test_acc_percent  \
# 0                         96.2                         98.7
#
#    pred3_top1_test_acc_percent  pred3_top3_test_acc_percent  \
# 0                         71.5                         95.2
#
#    pred3_top5_test_acc_percent
# 0                         97.7

# %% [markdown]
# # Check Vector Shape inside the model

# %%
import torch
from src.arch.cnn_ed_gru_model import CnnEdGruModel

# Create sample input
batch_size = 1
seq_len = 7
out_len = 3
feature_len = 5
x = torch.randn(batch_size, seq_len, feature_len)

# Initialize model
model = CnnEdGruModel(
    cnn_channels=[243, 243, 243],
    feature_len=feature_len,
    num_classes=64,
    rnn_num_layers=1,
    rnn_hidden_size=486,
    rnn_dropout=0.0,
    out_len=3,
    enable_logging=True
)

# Forward pass
output, hidden = model(x)
# Out:
# 2025-05-20 15:20:21.260 | INFO     | src.arch.cnn_ed_gru_model:forward:109 - x shape: torch.Size([1, 7, 5])
# 2025-05-20 15:20:21.261 | INFO     | src.arch.cnn_ed_gru_model:forward:117 - x shape after reshape: torch.Size([1, 5, 7])
# 2025-05-20 15:20:21.264 | INFO     | src.arch.cnn_ed_gru_model:forward:129 - x shape after conv: torch.Size([1, 243, 7])
# 2025-05-20 15:20:21.264 | INFO     | src.arch.cnn_ed_gru_model:forward:135 - x shape after reshape: torch.Size([1, 7, 243])
# 2025-05-20 15:20:21.268 | INFO     | src.arch.cnn_ed_gru_model:forward:141 - encoder_output shape: torch.Size([1, 7, 486])
# 2025-05-20 15:20:21.269 | INFO     | src.arch.cnn_ed_gru_model:forward:142 - encoder_hidden shape: torch.Size([1, 1, 486])
# 2025-05-20 15:20:21.269 | INFO     | src.arch.cnn_ed_gru_model:forward:148 - decoder_input shape: torch.Size([1, 1, 486])
# 2025-05-20 15:20:21.270 | INFO     | src.arch.cnn_ed_gru_model:forward:154 - expanded_input shape: torch.Size([1, 4, 486])
# 2025-05-20 15:20:21.272 | INFO     | src.arch.cnn_ed_gru_model:forward:161 - decoder_output shape: torch.Size([1, 4, 486])
# 2025-05-20 15:20:21.273 | INFO     | src.arch.cnn_ed_gru_model:forward:162 - decoder_hidden shape: torch.Size([1, 1, 486])
# 2025-05-20 15:20:21.274 | INFO     | src.arch.cnn_ed_gru_model:forward:168 - output shape: torch.Size([1, 4, 64])
